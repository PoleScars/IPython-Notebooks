# %%
#Imports numpy and matplotlib
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

# %%
'''library for pattern matching. 
Allows use of * and ? wild cards
only function is also glob
used by glob.glob('search parameters')'''
import glob

# %%
'''Shell commands do not play well with comment lines
The next few lines 'cd' the 'pwd' into the 'data' directory'''
# Out:
# "Shell commands do not play well with comment lines\nThe next few lines 'cd' the 'pwd' into the 'data' directory"

# %%
pwd #calls 'present working directory'
# Out:
# u'C:\\Users\\z3492622\\Documents\\IPython Notebooks'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 56C1-FBDF
#
#  Directory of C:\Users\z3492622\Documents\IPython Notebooks
#
# 16/04/2015  10:06    <DIR>          .
# 16/04/2015  10:06    <DIR>          ..
# 15/04/2015  17:14                57 .gitignore
# 14/04/2015  16:44    <DIR>          .ipynb_checkpoints
# 10/04/2015  16:56             5,509 Casting Volume Calcs.ipynb
# 15/04/2015  17:29             5,390 EDS Plot Generation.ipynb
# 15/04/2015  17:33    <DIR>          Python Scripts
# 17/02/2015  11:04    <DIR>          python-novice-inflammation-gh-pages
# 16/04/2015  10:07           325,586 ResBaz Day 2 - Machine.ipynb
#                4 File(s)        336,542 bytes
#                5 Dir(s)  612,967,424,000 bytes free

# %%
cd python-novice-inflammation-gh-pages/
# Out:
# C:\Users\z3492622\Documents\IPython Notebooks\python-novice-inflammation-gh-pages

# %%
cd data
# Out:
# C:\Users\z3492622\Documents\IPython Notebooks\python-novice-inflammation-gh-pages\data

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 56C1-FBDF
#
#  Directory of C:\Users\z3492622\Documents\IPython Notebooks\python-novice-inflammation-gh-pages\data
#
# 17/02/2015  11:04    <DIR>          .
# 17/02/2015  11:04    <DIR>          ..
# 17/02/2015  11:04             5,365 inflammation-01.csv
# 17/02/2015  11:04             5,314 inflammation-02.csv
# 17/02/2015  11:04             5,127 inflammation-03.csv
# 17/02/2015  11:04             5,367 inflammation-04.csv
# 17/02/2015  11:04             5,345 inflammation-05.csv
# 17/02/2015  11:04             5,330 inflammation-06.csv
# 17/02/2015  11:04             5,342 inflammation-07.csv
# 17/02/2015  11:04             5,127 inflammation-08.csv
# 17/02/2015  11:04             5,327 inflammation-09.csv
# 17/02/2015  11:04             5,342 inflammation-10.csv
# 17/02/2015  11:04             5,127 inflammation-11.csv
# 17/02/2015  11:04             5,340 inflammation-12.csv
# ...

# %%
'Defines a function to plot a file'
def analyze(fname):

    data = np.loadtxt(fname, delimiter=',')

    plt.figure(figsize=(10.0, 3.0))

    plt.subplot(1, 3, 1)
    plt.ylabel('average')
    plt.plot(data.mean(0))

    plt.subplot(1, 3, 2)
    plt.ylabel('max')
    plt.plot(data.max(0))

    plt.subplot(1, 3, 3)
    plt.ylabel('min')
    plt.plot(data.min(0))

    plt.tight_layout()
    plt.show()

# %%
'Runs function on a file'
analyze('inflammation-01.csv')

# %%
glob.glob('infl*.csv')
# Out:
# ['inflammation-01.csv',
#  'inflammation-02.csv',
#  'inflammation-03.csv',
#  'inflammation-04.csv',
#  'inflammation-05.csv',
#  'inflammation-06.csv',
#  'inflammation-07.csv',
#  'inflammation-08.csv',
#  'inflammation-09.csv',
#  'inflammation-10.csv',
#  'inflammation-11.csv',
#  'inflammation-12.csv']

# %%
print glob.glob('*infl*.csv')
# Out:
# ['inflammation-01.csv', 'inflammation-02.csv', 'inflammation-03.csv', 'inflammation-04.csv', 'inflammation-05.csv', 'inflammation-06.csv', 'inflammation-07.csv', 'inflammation-08.csv', 'inflammation-09.csv', 'inflammation-10.csv', 'inflammation-11.csv', 'inflammation-12.csv']

# %%
Inflam = glob.glob('*infl*.csv')

# %%
for fname in Inflam:
    print fname
    analyze(fname)
# Out:
# inflammation-01.csv
# inflammation-02.csv
# inflammation-03.csv
# inflammation-04.csv
# inflammation-05.csv
# inflammation-06.csv
# inflammation-07.csv
# inflammation-08.csv
# inflammation-09.csv
# inflammation-10.csv
# inflammation-11.csv
# inflammation-12.csv

# %%
num = 37
if num > 100:
    print 'greater'
else:
    print 'not greater'
# Out:
# not greater

# %%
num = 53
if num > 100:
    print 'greater'

# %%
def sign(num):
    '''Determine sign of a number'''
    
    if num > 0:
        return 1
    elif num == 0:
        return 0
    else:
        return -1

# %%
sign(5)
# Out:
# 1

# %%
sign(-5)
# Out:
# -1

# %%
sign(0)
# Out:
# 0

# %%
if (1 > 0) and (-1 > 0):
    print 'both parts true'
else:
    print 'at least one part is false'
# Out:
# at least one part is false

# %%
if (1 < 0) or ('left' < 'right'):
    print 'at least one part is true'
# Out:
# at least one part is true

# %%
if '': print 'empty string is true'
if 'word': print 'word is true'
if []: print 'empty list is true'
if [1, 2, 3]: print 'non-empty list is true'
if 0: print 'zero is true'
if 1: print 'one is true'
# Out:
# word is true
# non-empty list is true
# one is true

# %%
print

# %%
print ' '

# %%
def near(num1, num2):
    if num1 >= num2*0.1:
        print str(num1) + ' is at least 10% of ' + str(num2)
    else:
        print str(num1) + ' is NOT at least 10% of ' + str(num2)

# %%
near(4, 10)
# Out:
# 4 is at least 10% of 10
